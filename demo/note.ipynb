# %%
import sys
from pathlib import Path
srcdir = Path(".").absolute().parent
srcdir = str(srcdir)

if srcdir not in sys.path:
    sys.path.append(srcdir)

# %% [markdown]
# # e2e test

# %%
import numpy as np
from IPython import display

# %% [markdown]
# ## util/file/load_wav

# %%
from subroutine.util.file import load_wav

# %%
sr, w = load_wav("../data/jvsaudio.wav")
print(f"sampling rate: {sr}")
print(f"waveform shape: {w.shape}")
print(f"waveform dtype: {w.dtype}")
display.Audio(w, rate=sr)
# Out:
# sampling rate: 24000
# waveform shape: (206905,)
# waveform dtype: int16
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sr, w = load_wav("../data/jvsaudio.wav", sr=12000)
print(f"sampling rate: {sr}")
print(f"waveform shape: {w.shape}")
print(f"waveform dtype: {w.dtype}")
# Out:
# sampling rate: 12000
# waveform shape: (103452,)
# waveform dtype: float64

# %%
sr, w = load_wav("../data/jvsaudio.wav", dtype=np.int16)
print(f"sampling rate: {sr}")
print(f"waveform shape: {w.shape}")
print(f"waveform dtype: {w.dtype}")
# Out:
# sampling rate: 24000
# waveform shape: (206905,)
# waveform dtype: int16
